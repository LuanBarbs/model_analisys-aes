# %%
import pandas as pd

# %%
df = pd.read_csv("../dataset/output/avalia_saida.csv")

df_l = df.query("id == 'GPT4'")
df_l["EX_label"].value_counts() # IP_label # EX_label
# Out:
# 0    20
# Name: EX_label, dtype: int64
